# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time
from webdriver_manager.chrome import ChromeDriverManager
import re

# %%
driver = webdriver.Chrome('chromedriver.exe')
time.sleep(2)

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
driver.maximize_window()

# %%
rank = []

try:
    videorank = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for ranks in videorank:
        rank.append(ranks.text)
except NoSuchElementException:
    rank.append('No details available')
except StaleElementReferenceException:
    rank.append('No details available')
    
name = []
    
try:
    videonames = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for video in videonames:
        name.append(video.text)
except NoSuchElementException:
    name.append('No details available')
except StaleElementReferenceException:
    name.append('No details available')   

uploader = []
    
try:
    upload = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for upldr in upload:
        uploader.append(upldr.text)
except NoSuchElementException:
    uploader.append('No details available')
except StaleElementReferenceException:
    uploader.append('No details available')    
    
views = []
    
try:
    videoviews = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for vv in videoviews:
        views.append(vv.text)
except NoSuchElementException:
    views.append('No details available')
except StaleElementReferenceException:
    views.append('No details available')     

date = []
    
try:
    uploaddate = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for updd in uploaddate:
        date.append(updd.text)
except NoSuchElementException:
    date.append('No details available')
except StaleElementReferenceException:
    date.append('No details available')     



namelist = pd.DataFrame()
namelist['Video Rank'] = rank
namelist['Video Name'] = name
namelist['Artist'] = uploader
namelist['Upload Date'] = date
namelist['Video Views'] = views
namelist
# Out:
#    Video Rank                                       Video Name  \
# 0          1.                            "Baby Shark Dance"[3]
# 1          2.                                   "Despacito"[6]
# 2          3.                       "Johny Johny Yes Papa"[12]
# 3          4.                               "Shape of You"[13]
# 4          5.                              "See You Again"[15]
# 5          6.                                  "Bath Song"[20]
# 6          7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7          8.                "Phonics Song with Two Words"[22]
# 8          9.   "Masha and the Bear – Recipe for Disaster"[23]
# 9         10.                                "Uptown Funk"[24]
# 10        11.                              "Gangnam Style"[25]
# 11        12.                             "Dame Tu Cosita"[30]
# 12        13.                          "Wheels on the Bus"[31]
# 13        14.                                      "Sugar"[32]
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
time.sleep(2)

url = "https://www.bcci.tv/"
driver.get(url)
driver.maximize_window()
time.sleep(2)

intmatch = driver.find_element_by_xpath("//li[@class='nav-item ml-0']")
intmatch.click()
time.sleep(2)


series = []

seriesdriver = driver.find_elements_by_xpath("//span[@class='ng-binding']")

for ser in seriesdriver:
    series.append(ser.text)
series

matchtime = []

matchtimedriver = driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']")

for time in matchtimedriver:
    matchtime.append(time.text)
matchtime


matchdate = []

matchdatedriver = driver.find_elements_by_xpath("//h5[@class='ng-binding']")

for date in matchdatedriver:
    matchdate.append(date.text)
matchdate

matchvenue = []

matchvenuedriver = driver.find_elements_by_xpath("//span[@class='ng-binding ng-scope']")

for venue in matchvenuedriver:
    matchvenue.append(venue.text)
matchvenue

urls = []

urldriver = driver.find_elements_by_xpath("//div[@class='fixture-card-bottom']/a")

for link in urldriver:
    urls.append(link.get_attribute('href'))
urls

import time
match = []

for link in urls:                 
    driver.get(link)
    time.sleep(2)
    
    try:                    
        matchtitle =driver.find_element_by_xpath("/html/body/div[3]/div/div[1]/div[3]/div[6]/div[4]/div[2]/div[2]/div/div/ul/li[2]/span[2]")
        match.append(matchtitle.text)
    except NoSuchElementException:
        match.append('No details available')
        
match
# Out:
# ['India VS Sri Lanka',
#  'Pakistan Women VS India Women',
#  'New Zealand Women VS India Women',
#  'West Indies Women VS India Women',
#  'India VS Sri Lanka',
#  'England Women VS India Women',
#  'India Women VS Australia Women',
#  'India Women VS Bangladesh Women']

# %%
matchlist = pd.DataFrame()
matchlist['Series Name'] = series
matchlist['Match'] = match
matchlist['Match Date'] = matchdate
matchlist['Match Time'] = matchtime
matchlist['Venue'] = matchvenue
matchlist

#No match format available on the details page.
# Out:
#                                 Series Name                             Match  \
# 0  SRI LANKA TOUR OF INDIA TEST SERIES 2022                India VS Sri Lanka
# 1                 ICC WOMENS WORLD CUP 2022     Pakistan Women VS India Women
# 2                 ICC WOMENS WORLD CUP 2022  New Zealand Women VS India Women
# 3                 ICC WOMENS WORLD CUP 2022  West Indies Women VS India Women
# 4  SRI LANKA TOUR OF INDIA TEST SERIES 2022                India VS Sri Lanka
# 5                 ICC WOMENS WORLD CUP 2022      England Women VS India Women
# 6                 ICC WOMENS WORLD CUP 2022    India Women VS Australia Women
# 7                 ICC WOMENS WORLD CUP 2022   India Women VS Bangladesh Women
#
#     Match Date   Match Time                                          Venue
# 0   4 MAR 2022  9:30 AM IST  Punjab Cricket Association IS Bindra Stadium,
# 1   6 MAR 2022  6:30 AM IST                                      Bay Oval,
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
time.sleep(2)

url = "https://www.statisticstimes.com/"
driver.get(url)
driver.maximize_window()
time.sleep(2)

economybtn = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
economybtn.click()

time.sleep(2)

indiabtn = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
indiabtn.click()
time.sleep(2)

# %%
indstatesbtn = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
indstatesbtn.click()
time.sleep(2)

# %%
gdprank = []

try:
    gdprankdriver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
    for rank in gdprankdriver:
        gdprank.append(rank.text)
except NoSuchElementException:
    gdprank.append('No details available')
except StaleElementReferenceException:
    gdprank.append('No details available')

gdprank

gdpstate = []

try:
    gdpstatedriver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
    for state in gdpstatedriver:
        gdpstate.append(state.text)
except NoSuchElementException:
    gdpstate.append('No details available')
except StaleElementReferenceException:
    gdpstate.append('No details available')

gdpstate

gsdp1920 = []

try:
    gsdp1920driver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]")
    for gsdp1 in gsdp1920driver:
        gsdp1920.append(gsdp1.text)
except NoSuchElementException:
    gsdp1920.append('No details available')
except StaleElementReferenceException:
    gsdp1920.append('No details available')

gsdp1920

gsdp1819 = []

try:
    gsdp1819driver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]")
    for gsdp2 in gsdp1819driver:
        gsdp1819.append(gsdp2.text)
except NoSuchElementException:
    gsdp1819.append('No details available')
except StaleElementReferenceException:
    gsdp1819.append('No details available')

gsdp1819


gsdpshare = []

try:
    gsdpsharedriver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]")
    for share in gsdpsharedriver:
        gsdpshare.append(share.text)
except NoSuchElementException:
    gsdpshare.append('No details available')
except StaleElementReferenceException:
    gsdpshare.append('No details available')

gsdpshare

gdp1 = []

try:
    gdp1driver = driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]")
    for gdp in gdp1driver:
        gdp1.append(gdp.text)
except NoSuchElementException:
    gdp1.append('No details available')
except StaleElementReferenceException:
    gdp1.append('No details available')

gsdpshare



indiagdplist = pd.DataFrame()
indiagdplist['Rank'] = gdprank
indiagdplist['State'] = gdpstate
indiagdplist['GSDP (19-20)'] = gsdp1920
indiagdplist['GSDP (18-19)'] = gsdp1819
indiagdplist['GSDP Share'] = gsdpshare
indiagdplist['GDP in Millions'] = gdp1
indiagdplist.head(33)
# Out:
#    Rank                      State GSDP (19-20) GSDP (18-19) GSDP Share  \
# 0     1                Maharashtra            -    2,632,792     13.94%
# 1     2                 Tamil Nadu    1,845,853    1,630,208      8.63%
# 2     3              Uttar Pradesh    1,687,818    1,584,764      8.39%
# 3     4                    Gujarat            -    1,502,899      7.96%
# 4     5                  Karnataka    1,631,977    1,493,127      7.91%
# 5     6                West Bengal    1,253,832    1,089,898      5.77%
# 6     7                  Rajasthan    1,020,989      942,586      4.99%
# 7     8             Andhra Pradesh      972,782      862,957      4.57%
# 8     9                  Telangana      969,604      861,031      4.56%
# 9    10             Madhya Pradesh      906,672      809,592      4.29%
# 10   11                     Kerala            -      781,653      4.14%
# 11   12                      Delhi      856,112      774,870      4.10%
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
time.sleep(2)

url = "https://github.com/"
driver.get(url)
driver.maximize_window()
time.sleep(2)

explorebtn = driver.find_element_by_xpath("//details[@class='HeaderMenu-details details-overlay details-reset width-full']")
explorebtn.click()

time.sleep(1)

trendingbtn = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
try:
    trendingbtn.click()
except:
    driver.get(trendingbtn.get_attribute('href'))
time.sleep(2)

repositorname = []

try:
    repnamedriver = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
    for name in repnamedriver:
        repositorname.append(name.text)
except NoSuchElementException:
    repositorname.append('No details available')
except StaleElementReferenceException:
    repositorname.append('No details available')

repositorname

urls = []

urldriver = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")

for link in urldriver:
    urls.append(link.get_attribute('href'))
urls

time.sleep(2)

contributors = []
replanguage = []
repdesc = []

for link in urls:                 
    driver.get(link)
    time.sleep(2)
    
    try:                    
        cont =driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        contributors.append(cont.text)
    except NoSuchElementException:
        contributors.append('No details available')
        
    try:                    
        replang =driver.find_element_by_xpath("//li[@class='d-inline']//a//span")
        replanguage.append(replang.text)
    except NoSuchElementException:
        replanguage.append('No details available')
        
    try:                    
        rdesc =driver.find_element_by_xpath("//p[@class='f4 my-3']")
        repdesc.append(rdesc.text)
    except NoSuchElementException:
        repdesc.append('No details available')
        
repdesc


githublist = pd.DataFrame()
githublist['Repo Name'] = repositorname
githublist['Repo Desc'] = repdesc
githublist['Repo Lang'] = replanguage
githublist['Repo Contributors'] = contributors
githublist['URL'] = urls
githublist
# Out:
#                                            Repo Name  \
# 0                              almerico / bombardier
# 1                                  iaddis / metalnes
# 2                             AppFlowy-IO / AppFlowy
# 3   cat-milk / Anime-Girls-Holding-Programming-Books
# 4                     HashLips / hashlips_art_engine
# 5                              freqtrade / freqtrade
# 6                          erkexzcx / stoppropaganda
# 7                        AlexTrushkovsky / NoWarDDoS
# 8                                  MHProDev / MHDDoS
# 9                             ajax-lives / NoRussian
# 10                    Developer-Y / cs-video-courses
# 11                             palahsu / DDoS-Ripper
# 12          curated-intel / Ukraine-Cyber-Operations
# 13                            techchipnet / CamPhish
# 14                             ytdl-org / youtube-dl
# 15                        github / advisory-database
# 16                cyprosecurity / API-SecurityEmpire
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

url = "https://www.billboard.com/"
driver.get(url)
time.sleep(2)

hot100btn = driver.find_element_by_xpath("//*[@id='main-wrapper']/header/div[2]/div/nav/ul/li[1]/a")
hot100btn.click()

time.sleep(5)

# %%
songname = []

try:
    songnamedriver= driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li/h3")
    for name in songnamedriver:
        songname.append(name.text.strip(""))
except NoSuchElementException:
    songname.append('No details available')

songname

artistname = []

try:
    artistnamedriver= driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[1]/span")
    for aname in artistnamedriver:
        artistname.append(aname.text)
except NoSuchElementException:
    artistname.append('No details available')

artistname


lastweekrank = []

try:
    lastweekrankdriver= driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[4]")
    for lweek in lastweekrankdriver:
        lastweekrank.append(lweek.text)
except NoSuchElementException:
    lastweekrank.append('No details available')

lastweekrank

peakposrank = []

try:
    peakposrankdriver= driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[5]")
    for pprank in peakposrankdriver:
        peakposrank.append(pprank.text)
except NoSuchElementException:
    peakposrank.append('No details available')

peakposrank


weaksonchart = []

try:
    weaksonchartdriver= driver.find_elements_by_xpath("//li[@class='lrv-u-width-100p']/ul/li[6]")
    for wkoncrt in weaksonchartdriver:
        weaksonchart.append(wkoncrt.text)
except NoSuchElementException:
    weaksonchart.append('No details available')

weaksonchart

billboardlist = pd.DataFrame()
billboardlist['Song Name'] = songname
billboardlist['Artist'] = artistname
billboardlist['Last Week'] = lastweekrank
billboardlist['Peak POS'] = peakposrank
billboardlist['Weeks on Chart'] = weaksonchart
billboardlist.head(10)
# Out:
#                    Song Name  \
# 0  We Don't Talk About Bruno
# 1                 Heat Waves
# 2                 Easy On Me
# 3                    abcdefu
# 4                       Stay
# 5              Super Gremlin
# 6                    Shivers
# 7                      Ghost
# 8          Thats What I Want
# 9                   Pushin P
#
#                                               Artist Last Week Peak POS  \
# 0  Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...         1        1
# 1                                      Glass Animals         4        2
# 2                                              Adele         3        1
# 3                                              GAYLE         7        4
# 4                      The Kid LAROI & Justin Bieber         5        1
# 5                                        Kodak Black         6        5
# 6                                         Ed Sheeran         8        4
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

url = "https://www.naukri.com/"
driver.get(url)
time.sleep(2)

userinput = input('Enter the Search Keyword: ')

time.sleep(2)

search = driver.find_element_by_class_name("suggestor-input")
search
time.sleep(2)

search.send_keys(userinput)
time.sleep(2)

searchbtn = driver.find_element_by_xpath("//div[@class='qsbSubmit']")
searchbtn
searchbtn.click()
# Out:
# Enter the Search Keyword: Data science

# %%
jobname = []

try:
    jobnamedriver = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
    for name in jobnamedriver:
        jobname.append(name.text)
except NoSuchElementException:
    jobname.append('No details available')

jobname

companyname = []

try:
    companynamedriver = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
    for cname in companynamedriver:
        companyname.append(cname.text)
except NoSuchElementException:
    companyname.append('No details available')

companyname

keyskills = []

try:
    keyskillsdriver = driver.find_elements_by_xpath("//ul[@class='tags has-description']")
    for kskills in keyskillsdriver:
        keyskills.append(kskills.text.replace('\n', ", "))
except NoSuchElementException:
    keyskills.append('No details available')

keyskills


joblocation = []

try:
    joblocationdriver = driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']")
    for jlocation in joblocationdriver:
        joblocation.append(jlocation.text.replace('\n', ", "))
except NoSuchElementException:
    joblocation.append('No details available')

joblocation

urls = []

urldriver = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for link in urldriver:
        urls.append(link.get_attribute("href"))
urls

jobrole = []

for link in urls:                 
    driver.get(link)
    time.sleep(2)
    
    try:                    
        role =driver.find_element_by_xpath("//div[@class='details']/span")
        jobrole.append(role.text)
    except NoSuchElementException:
        jobrole.append('No details available')
        
jobrole
# Out:
# ['Data Analyst',
#  'Data Scientist',
#  'Analytics Consultant',
#  'Data Engineer',
#  'Business Analyst',
#  'No details available',
#  'Business Analyst',
#  'Data Analyst',
#  'No details available',
#  'Manager - Machine Learning',
#  'No details available',
#  'Business Analyst',
#  'No details available',
#  'Head - Analytics / BI',
#  'Business Analyst',
#  'Data Analyst',
#  'No details available',
#  'Analytics Consultant',
#  'Business Analyst',
#  'Business Analyst']

# %%
naukrijoblist = pd.DataFrame()
naukrijoblist ['Job Name'] = jobname
naukrijoblist ['Designation'] = jobrole
naukrijoblist ['Company'] = companyname
naukrijoblist ['Skills they hire for'] = keyskills
naukrijoblist ['Location'] = joblocation
naukrijoblist ['Job Link'] = urls
naukrijoblist
# Out:
#                                              Job Name  \
# 0   Job | Business Analyst | RPA (Uipath) II HCL T...
# 1                           Opening with Data Science
# 2                    Product Owner - Data Engineering
# 3                        Hiring For Big Data Engineer
# 4                       Business Analyst - Automation
# 5           Assistant Manager/Manager- Data Scientist
# 6         Urgent Hiring - Maritime Logistics Research
# 7                                   SAS Fraud Analyst
# 8                           Technical Project Manager
# 9                                Machine Learning Ops
# 10             MSBI + Cosmos Developer- Urgent Hiring
# 11                                   Business Analyst
# 12                      RPA | UiPath Business Analyst
# 13  Senior Product Analyst / Associate Director - ...
# 14                                   Business Analyst
# 15                  We are hiring ESG Data Analyst!!!
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)
time.sleep(2)

# %%
bookrank = []
booktitle = []
bookauthor = []
bookvolumesales = []
bookpublisher = []
bookgenre = []

try:
    bookrankdriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[1]")
    for rank in bookrankdriver:
        bookrank.append(rank.text)
except NoSuchElementException:
    bookrank.append('No details available')

try:
    booktitledriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
    for title in booktitledriver:
        booktitle.append(title.text)
except NoSuchElementException:
    booktitle.append('No details available')
    

try:
    bookauthordriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for author in bookauthordriver:
        bookauthor.append(author.text)
except NoSuchElementException:
    bookauthor.append('No details available')
        
try:
    bookvolumesalesdriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for volume in bookvolumesalesdriver:
        bookvolumesales.append(volume.text)
except NoSuchElementException:
    bookvolumesales.append('No details available')    
    
try:
    bookpublisherdriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for publisher in bookpublisherdriver:
        bookpublisher.append(publisher.text)
except NoSuchElementException:
    bookpublisher.append('No details available')  
    
try:
    bookgenredriver = driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for genre in bookgenredriver:
        bookgenre.append(genre.text)
except NoSuchElementException:
    bookgenre.append('No details available')  
    

booklist = pd.DataFrame()
booklist ['Rank'] = bookrank
booklist ['Title'] = booktitle
booklist ['Author'] = bookauthor
booklist ['Sales in Volume'] = bookvolumesales
booklist ['Publisher'] = bookpublisher
booklist ['Genre'] = bookgenre
booklist.head(10)
# Out:
#   Rank                                              Title         Author  \
# 0    1                                  Da Vinci Code,The     Brown, Dan
# 1    2               Harry Potter and the Deathly Hallows  Rowling, J.K.
# 2    3           Harry Potter and the Philosopher's Stone  Rowling, J.K.
# 3    4          Harry Potter and the Order of the Phoenix  Rowling, J.K.
# 4    5                               Fifty Shades of Grey   James, E. L.
# 5    6                Harry Potter and the Goblet of Fire  Rowling, J.K.
# 6    7            Harry Potter and the Chamber of Secrets  Rowling, J.K.
# 7    8           Harry Potter and the Prisoner of Azkaban  Rowling, J.K.
# 8    9                                  Angels and Demons     Brown, Dan
# 9   10  Harry Potter and the Half-blood Prince:Childre...  Rowling, J.K.
#
#   Sales in Volume     Publisher                        Genre
# 0       5,094,805    Transworld  Crime, Thriller & Adventure
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(2)

# %%
seriesname = []
seriesyearsspan = []
seriesgenre = []
seriesruntime = []
seriesratings = []
seriesvotes = []

try:
    namedriver = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    for name in namedriver [:10]:
        seriesname.append(name.text)
except NoSuchElementException:
    seriesname.append('No details available')

try:
    seriesyearsspandriver = driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
    for years in seriesyearsspandriver [:10]:
        seriesyearsspan.append(years.text)
except NoSuchElementException:
    seriesyearsspan.append('No details available')

try:
    seriesgenredriver = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]")
    for genre in seriesgenredriver [:10]:
        seriesgenre.append(genre.text)
except NoSuchElementException:
    seriesgenre.append('No details available')

try:
    seriesruntimedriver = driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]")
    for runtime in seriesruntimedriver [:10]:
        seriesruntime.append(runtime.text)
except NoSuchElementException:
    seriesruntime.append('No details available')

try:
    seriesratingsdriver = driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']/div/span[2]")
    for ratings in seriesratingsdriver [:10]:
        seriesratings.append(ratings.text)
except NoSuchElementException:
    seriesratings.append('No details available')        

try:
    seriesvotesdriver = driver.find_elements_by_xpath("//span[@name='nv']")
    for votes in seriesvotesdriver [:10]:
        seriesvotes.append(votes.text)
except NoSuchElementException:
    seriesvotes.append('No details available')
    

seriesvotes


imdblist = pd.DataFrame()
imdblist ['Name'] = seriesname
imdblist ['Years Span'] = seriesyearsspan
imdblist ['Genre'] = seriesgenre
imdblist ['Run Time'] = seriesruntime
imdblist ['Ratings'] = seriesratings
imdblist ['Votes'] = seriesvotes
imdblist.head(10)
# Out:
#                       Name   Years Span                     Genre Run Time  \
# 0          Game of Thrones  (2011–2019)  Action, Adventure, Drama   57 min
# 1          Stranger Things     (2016– )    Drama, Fantasy, Horror   51 min
# 2         The Walking Dead  (2010–2022)   Drama, Horror, Thriller   44 min
# 3           13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller   60 min
# 4                  The 100  (2014–2020)    Drama, Mystery, Sci-Fi   43 min
# 5  Orange Is the New Black  (2013–2019)      Comedy, Crime, Drama   59 min
# 6                Riverdale     (2017– )     Crime, Drama, Mystery   45 min
# 7           Grey's Anatomy     (2005– )            Drama, Romance   41 min
# 8                The Flash     (2014– )  Action, Adventure, Drama   43 min
# 9                    Arrow  (2012–2020)  Action, Adventure, Crime   42 min
#
#   Ratings      Votes
# 0     9.2  1,957,638
# 1     8.7    967,213
# 2     8.1    932,500
# 3     7.5    279,171
# 4     7.6    239,352
# ...

# %%
import time

driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

alldatasetbtn = driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a")
alldatasetbtn.click()

time.sleep(2)

# %%
datasetname = []
datatypes = []
datatask = []
dataattributetype = []
noofinstances = []
noofattribute = []
datasetyear = []

try:
    datasetnamedriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for name in datasetnamedriver [:9]:
        datasetname.append(name.text)
except NoSuchElementException:
    datasetname.append('No details available')

try:
    datatypesdriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for types in datatypesdriver [1:10]:
        datatypes.append(types.text)
except NoSuchElementException:
    datatypes.append('No details available')
    
try:
    datataskdriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for task in datataskdriver [1:10]:
        datatask.append(task.text)
except NoSuchElementException:
    datatask.append('No details available')
    
try:
    dataattributetypedriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for attribute in dataattributetypedriver [1:10]:
        dataattributetype.append(attribute.text)
except NoSuchElementException:
    dataattributetype.append('No details available')    
    
try:
    noofinstancesdriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for instances in noofinstancesdriver [1:10]:
        noofinstances.append(instances.text)
except NoSuchElementException:
    noofinstances.append('No details available')    

try:
    noofattributedriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for attrb in noofattributedriver [1:10]:
        noofattribute.append(attrb.text)
except NoSuchElementException:
    noofattribute.append('No details available')    

try:
    datasetyeardriver = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for year in datasetyeardriver [1:10]:
        datasetyear.append(year.text)
except NoSuchElementException:
    datasetyear.append('No details available')    




datasetlist = pd.DataFrame()
datasetlist ['Data Set Name'] = datasetname
datasetlist ['Data Types'] = datatypes
datasetlist ['Data Task'] = datatask
datasetlist ['Attribute Type'] = dataattributetype
datasetlist ['No of Instances'] = noofinstances
datasetlist ['No of Attribute'] = noofattribute
datasetlist ['Year'] = datasetyear
datasetlist
# Out:
#                   Data Set Name     Data Types             Data Task  \
# 0                       Abalone  Multivariate        Classification
# 1                         Adult  Multivariate        Classification
# 2                     Annealing  Multivariate        Classification
# 3  Anonymous Microsoft Web Data                 Recommender-Systems
# 4                    Arrhythmia  Multivariate        Classification
# 5         Artificial Characters  Multivariate        Classification
# 6          Audiology (Original)  Multivariate        Classification
# 7      Audiology (Standardized)  Multivariate        Classification
# 8                      Auto MPG  Multivariate            Regression
#
#                 Attribute Type No of Instances No of Attribute   Year
# 0  Categorical, Integer, Real            4177               8   1995
# 1        Categorical, Integer           48842              14   1996
# 2  Categorical, Integer, Real             798              38
# ...

# %%
url = "https://www.guru99.com/"
page = requests.get(url)
soup = BeautifulSoup(page.content)

driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
driver.maximize_window()

error = driver.find_element_by_xpath('//*[@id="java_technologies"]/li[3]/a').get_attribute('href')
driver.get(error)
time.sleep(3)
exception = driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').get_attribute('href')
driver.get(exception)

Data = []
table = driver.find_elements_by_xpath("//table[@class='table table-striped']//td")
for i in table:
    try:
        Data.append(i.text)
    except NoSuchElementException:
        Data.append('-')

Name = []
for i in range(2,len(Data),2):
    Name.append(Data[i])

Description = []
for i in range(3,len(Data),2):
    Description.append(Data[i])

df=pd.DataFrame({"Exception name": Name, "Exception description": Description})
df
# Out:
# Legality Response number from our URL is: <Response [403]>
#                          Exception name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# ...
