# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
shoes = webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.flipkart.com/"
shoes.get(url)

# %%
prod_search = shoes.find_element_by_class_name('_3704LK')
prod_search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="99a85cf7-4373-40b1-9ef9-012c1eb53f9f")>

# %%
prod_search.send_keys('sneakers')

# %%
submit_button = shoes.find_element_by_xpath('/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
submit_button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="ea0bd275-8ff7-4c5a-965a-14a1ad60466d")>

# %%
submit_button.click()

# %%
brand_name1 = shoes.find_elements_by_xpath('//div[@class="_2WkVRV"]')
prod_name1_1 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[:4]
prod_name1_2 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[:1]
prod_name1_3 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[4:5]
prod_name1_4 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[1:2]
prod_name1_5 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[5:16]
prod_name1_6 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[2:3]
prod_name1_7 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[16:19]
prod_name1_8 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[3:4]
prod_name1_9 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[19:23]
prod_name1_10 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[4:5]
prod_name1_11 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[23:24]
prod_name1_12 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[5:6]
prod_name1_13 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[24:28]
prod_name1_14 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[6:7]
prod_name1_15 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[28:]
prod_name1_16 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[7:]
prod_price1 = shoes.find_elements_by_xpath('//div[@class="_30jeq3"]')
prod_price1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="ce3a7a8d-64ad-4f21-9748-1a9a990da9f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="590954e8-4f2e-49bb-9430-d325a1e0d01a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="de5cf0ef-5e2b-4460-8294-d21a6c6a0b82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="3ac86053-ed3f-4c38-ba19-8efcfbe038d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="ef827b41-c63c-4de9-b6c2-8ef6669b74a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="adcd6f7e-01ed-4ab6-8dd8-ecabd3ab0a86")>,
# ...

# %%
Brandname = []

for name in brand_name1:
    Brandname.append(name.text)
Brandname

Prodname1 = []

for pname in prod_name1_1:
    Prodname1.append(pname.text)
Prodname1

Prodname2 = []

for pname in prod_name1_2:
    Prodname2.append(pname.text)
Prodname2

Prodname3 = []

for pname in prod_name1_3:
    Prodname3.append(pname.text)
Prodname3

Prodname4 = []

for pname in prod_name1_4:
    Prodname4.append(pname.text)
Prodname4

Prodname5 = []

for pname in prod_name1_5:
    Prodname5.append(pname.text)
Prodname5

Prodname6 = []

for pname in prod_name1_6:
    Prodname6.append(pname.text)
Prodname6

Prodname7 = []

for pname in prod_name1_7:
    Prodname7.append(pname.text)
Prodname7

Prodname8 = []

for pname in prod_name1_8:
    Prodname8.append(pname.text)
Prodname8

Prodname9 = []

for pname in prod_name1_9:
    Prodname9.append(pname.text)
Prodname9

Prodname10 = []

for pname in prod_name1_10:
    Prodname10.append(pname.text)
Prodname10

Prodname11 = []

for pname in prod_name1_11:
    Prodname11.append(pname.text)
Prodname11

Prodname12 = []

for pname in prod_name1_12:
    Prodname12.append(pname.text)
Prodname12

Prodname13 = []

for pname in prod_name1_13:
    Prodname13.append(pname.text)
Prodname13

Prodname14 = []

for pname in prod_name1_14:
    Prodname14.append(pname.text)
Prodname14

Prodname15 = []

for pname in prod_name1_15:
    Prodname15.append(pname.text)
Prodname15

Prodname16 = []

for pname in prod_name1_16:
    Prodname16.append(pname.text)
Prodname16

ProdusctDescription = list(Prodname1+Prodname2+Prodname3+Prodname4+Prodname5+Prodname6+Prodname7+Prodname8+Prodname9+Prodname10+Prodname11+Prodname12+Prodname13+Prodname14+Prodname15+Prodname16)
ProdusctDescription

Prodprice1 = []

for pprice in prod_price1:
    Prodprice1.append(pprice.text)
Prodprice1
# Out:
# ['₹449',
#  '₹499',
#  '₹398',
#  '₹449',
#  '₹220',
#  '₹499',
#  '₹242',
#  '₹449',
#  '₹948',
#  '₹499',
#  '₹348',
#  '₹449',
#  '₹359',
#  '₹398',
#  '₹345',
#  '₹442',
#  '₹499',
#  '₹298',
#  '₹449',
#  '₹598',
#  '₹499',
#  '₹499',
#  '₹189',
#  '₹499',
#  '₹499',
#  '₹299',
#  '₹379',
#  '₹499',
#  '₹499',
#  '₹399',
#  '₹429',
#  '₹499',
#  '₹599',
#  '₹574',
#  '₹299',
#  '₹499',
#  '₹649',
#  '₹499',
#  '₹499',
#  '₹898']

# %%
data = pd.DataFrame()
data ['Brand Name'] = Brandname
data ['Prod Desc'] = ProdusctDescription
data ['Price'] = Prodprice1
data.head(45)
# Out:
#          Brand Name                                          Prod Desc Price
# 0             AMICO                                   Sneakers For Men  ₹449
# 1     RODDICK SHOES  Fashion Outdoor Canvas Casual Light Weight Lac...  ₹499
# 2          Magnolia                                   Sneakers For Men  ₹398
# 3    luxury fashion  Luxury Fashionable casual sneaker shoes Sneake...  ₹449
# 4          URBANBOX                          Sneakers Sneakers For Men  ₹220
# 5            Labbin                                   Sneakers For Men  ₹499
# 6      Stefano Rads                            Classy Sneakers For Men  ₹242
# 7         India hub   luxury fashionable casual shoes Sneakers For Men  ₹449
# 8            Extoes  Modern Trendy Shoes Combo pack of 4 Sneakers F...  ₹948
# 9             Jabra  Perfect Combo Sport Shoes for Running Training...  ₹499
# 10       D-SNEAKERZ  Casual , Partywear Sneakers Shoes For Men's An...  ₹348
# ...

# %%
np_button = shoes.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]')
np_button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="9deb46d3-d585-49e5-ac56-b1e47aca0796")>

# %%
np_button.click()

# %%
brand_name2 = shoes.find_elements_by_xpath('//div[@class="_2WkVRV"]')
prod_name2_1 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[:6]
prod_name2_2 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[:3]
prod_name2_3 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[6:10]
prod_name2_4 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[2:3]
prod_name2_5 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[10:26]
prod_name2_6 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[3:4]
prod_name2_7 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[25:26]
prod_name2_8 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[5:]
prod_name2_9 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[27:]
prod_price2 = shoes.find_elements_by_xpath('//div[@class="_30jeq3"]')
prod_price2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="2ec5a999-d4c5-46ec-92da-cc192d7527d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="dece1797-9746-4db3-bd49-3ccfea1067cc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="dd845987-2f52-48cf-8b6e-0121d877d633")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="ecb716d5-5a28-4b56-9627-ea6a62807e78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="138a5b90-c257-4d84-a13f-6bc54d050428")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="1e7169d9-81b3-434a-ba6a-fcf8caffbf40")>,
# ...

# %%
Brandname1 = []

for name in brand_name2:
    Brandname1.append(name.text)
Brandname1

Prodname1 = []

for pname in prod_name2_1:
    Prodname1.append(pname.text)
Prodname1

Prodname2 = []

for pname in prod_name2_2:
    Prodname2.append(pname.text)
Prodname2

Prodname3 = []

for pname in prod_name2_3:
    Prodname3.append(pname.text)
Prodname3

Prodname4 = []

for pname in prod_name2_4:
    Prodname4.append(pname.text)
Prodname4

Prodname5 = []

for pname in prod_name2_5:
    Prodname5.append(pname.text)
Prodname5

Prodname6 = []

for pname in prod_name2_6:
    Prodname6.append(pname.text)
Prodname6

Prodname7 = []

for pname in prod_name2_7:
    Prodname7.append(pname.text)
Prodname7

Prodname8 = []

for pname in prod_name2_8:
    Prodname8.append(pname.text)
Prodname8

Prodname9 = []

for pname in prod_name2_9:
    Prodname9.append(pname.text)
Prodname9

ProdusctDescription1 = list(Prodname1+Prodname2+Prodname3+Prodname4+Prodname5+Prodname6+Prodname7+Prodname8+Prodname9)
ProdusctDescription1

Prodprice2 = []

for pprice in prod_price2:
    Prodprice2.append(pprice.text)
Prodprice2
# Out:
# ['₹399',
#  '₹199',
#  '₹499',
#  '₹479',
#  '₹451',
#  '₹298',
#  '₹680',
#  '₹749',
#  '₹799',
#  '₹438',
#  '₹489',
#  '₹499',
#  '₹555',
#  '₹799',
#  '₹399',
#  '₹699',
#  '₹499',
#  '₹449',
#  '₹499',
#  '₹920',
#  '₹2,998',
#  '₹429',
#  '₹920',
#  '₹920',
#  '₹599',
#  '₹448',
#  '₹245',
#  '₹920',
#  '₹499',
#  '₹499',
#  '₹640',
#  '₹399',
#  '₹630',
#  '₹499',
#  '₹498',
#  '₹2,899',
#  '₹367',
#  '₹599',
#  '₹499',
#  '₹499']

# %%
data1 = pd.DataFrame()
data1 ['Brand Name'] = Brandname1
data1 ['Prod Desc'] = ProdusctDescription1
data1 ['Price'] = Prodprice2
data1.head(45)
# Out:
#              Brand Name                                          Prod Desc  \
# 0               ESSENCE                         Casuals Sneakers For Women
# 1   World Wear Footwear  Latest Collection-1216 Stylish Casual Sports S...
# 2              ASTEROID  Original Luxury Branded Fashionable Men's Casu...
# 3              PEHANOSA                                   Sneakers For Men
# 4          Robbie jones  Casual Sneakers Black Shoes For Men Sneakers F...
# 5                RINDAS  Perfect Stylish Casual Shoes For Girls & Women...
# 6              RapidBox                                   Sneakers For Men
# 7             FOOTSTAIR                                   Sneakers For Men
# 8                 SPARX                            SM-439 Sneakers For Men
# 9                RINDAS                                 Sneakers For Women
# 10         K- FOOTLANCE                                   Sneakers For Men
# ...

# %%
np_button1 = shoes.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]')
np_button1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="ed63057e-8f86-463c-b5d2-f21e796a6671")>

# %%
np_button1.click()

# %%
brand_name3 = shoes.find_elements_by_xpath('//div[@class="_2WkVRV"]')[:20]
prod_name3_1 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[:13]
prod_name3_2 = shoes.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]')[:2]
prod_name3_3 = shoes.find_elements_by_xpath('//a[@class="IRpwTa"]')[13:18]
prod_price3 = shoes.find_elements_by_xpath('//div[@class="_30jeq3"]')[:20]
prod_price3
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="f5846d83-ccd5-496f-a124-20d34aa9c801")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="3ddb7f5f-07ef-453c-9309-84bb4bf0d968")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="7a066899-ec97-44db-a325-f9ca132de2d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="4133baa1-5792-41ba-84bc-266b1e1d0f54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="f19b139c-bd38-4c83-aff4-043b11bfa5e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5ec4d9e805a3179aa35214c73b179e62", element="50787d18-7f89-4529-894a-3989fe1617ef")>,
# ...

# %%
Brandname2 = []

for name in brand_name3:
    Brandname2.append(name.text)
Brandname2

Prodname1 = []

for pname in prod_name3_1:
    Prodname1.append(pname.text)
Prodname1

Prodname2 = []

for pname in prod_name3_2:
    Prodname2.append(pname.text)
Prodname2

Prodname3 = []

for pname in prod_name3_3:
    Prodname3.append(pname.text)
Prodname3

ProdusctDescription2 = list(Prodname1+Prodname2+Prodname3)
ProdusctDescription2

Prodprice3 = []

for pprice in prod_price3:
    Prodprice3.append(pprice.text)
Prodprice3
# Out:
# ['₹892',
#  '₹2,199',
#  '₹384',
#  '₹569',
#  '₹399',
#  '₹749',
#  '₹386',
#  '₹499',
#  '₹427',
#  '₹499',
#  '₹474',
#  '₹442',
#  '₹599',
#  '₹429',
#  '₹649',
#  '₹499',
#  '₹499',
#  '₹699',
#  '₹598',
#  '₹549']

# %%
data2 = pd.DataFrame()
data2 ['Brand Name'] = Brandname2
data2 ['Prod Desc'] = ProdusctDescription2
data2 ['Price'] = Prodprice3
data2.head(45)
# Out:
#         Brand Name                                          Prod Desc   Price
# 0            SPARX                            SM-162 Sneakers For Men    ₹892
# 1             PUMA  Puma Smash v2 L Perf Puma White-Puma Whi Sneak...  ₹2,199
# 2       D-SNEAKERZ  Casual , Partywear Sneakers Shoes For Men's An...    ₹384
# 3            Echor  Echor Men's Sneakers Fashion Lightweight Runni...    ₹569
# 4         KANEGGYE                                   Sneakers For Men    ₹399
# 5         Vellinto            Casual Sneakrs For Men Sneakers For Men    ₹749
# 6            Echor  Men's Canvas Low Top Sneakers Lace-up Classic ...    ₹386
# 7      MILESWALKER                                 Sneakers For Women    ₹499
# 8        Deals4you                                 Sneakers For Women    ₹427
# 9           VENDOZ  Girls Stylish Casual Sports Shoe Sneakers For ...    ₹499
# 10    Robbie jones  Casual Sneakers White Shoes For Men Sneakers F...    ₹474
# ...

# %%
pd.concat([data, data1, data2])
# Out:
#         Brand Name                                          Prod Desc Price
# 0            AMICO                                   Sneakers For Men  ₹449
# 1    RODDICK SHOES  Fashion Outdoor Canvas Casual Light Weight Lac...  ₹499
# 2         Magnolia                                   Sneakers For Men  ₹398
# 3   luxury fashion  Luxury Fashionable casual sneaker shoes Sneake...  ₹449
# 4         URBANBOX                          Sneakers Sneakers For Men  ₹220
# ..             ...                                                ...   ...
# 15         Zapatoz                                 Sneakers For Women  ₹499
# 16           ASIAN  Skypy-31 Walking Shoes,Training Shoes,Sneakers...  ₹499
# 17           CLYMB                                   Sneakers For Men  ₹699
# 18           BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men  ₹598
# 19             GVR                                   Sneakers For Men  ₹549
#
# [100 rows x 3 columns]
