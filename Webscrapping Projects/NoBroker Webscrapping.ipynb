# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...&radius=2.0&city=bangalore&locality=Indiranagar,&locality=Jayanagar,&locality=Rajajinagar'

# %%
nobroker = requests.get(url)
nobroker
# Out:
# <Response [200]>

# %%
nobroker.content
soup = BeautifulSoup (nobroker.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="794951570520699" property="fb:pages"/>
#   <link href="https://www.nobroker.in" rel="canonical"/>
#   <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//assets.nobroker.in" rel="dns-prefetch"/>
#   <link href="//images.nobroker.in" rel="dns-prefetch"/>
#   <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon">
#    <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
#    <meta charset="utf-8"/>
#    <meta charset="utf-8"/>
#    <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
#    <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
#    <meta content="#fd3752" name="theme-color"/>
# ...

# %%
nobroker = soup.find_all('h2', class_="heading-6 font-semi-bold nb__25Cl7")
nobroker
# Out:
# [<h2 class="heading-6 font-semi-bold nb__25Cl7"><span itemprop="name">3 BHK Flat  For Sale  In Shanti Park Apartments In Jayanagara 9th Block, Jayanagar</span> <svg class="" style="width:24px;height:24px;margin:2px" type="link" viewbox="0 0 24 24"><path class="" d="M18,10.82a1,1,0,0,0-1,1V19a1,1,0,0,1-1,1H5a1,1,0,0,1-1-1V8A1,1,0,0,1,5,7h7.18a1,1,0,0,0,0-2H5A3,3,0,0,0,2,8V19a3,3,0,0,0,3,3H16a3,3,0,0,0,3-3V11.82A1,1,0,0,0,18,10.82Zm3.92-8.2a1,1,0,0,0-.54-.54A1,1,0,0,0,21,2H15a1,1,0,0,0,0,2h3.59L8.29,14.29a1,1,0,0,0,0,1.42,1,1,0,0,0,1.42,0L20,5.41V9a1,1,0,0,0,2,0V3A1,1,0,0,0,21.92,2.62Z" fill="#000000"></path></svg></h2>,
# ...

# %%
HouseTitle = []

for title in nobroker:
    title = title.get_text()
    HouseTitle.append(title)
HouseTitle
# Out:
# ['3 BHK Flat  For Sale  In Shanti Park Apartments In Jayanagara 9th Block, Jayanagar ',
#  '3 BHK Flat  For Sale  In Madhavaram Metropolitan In Jayanagar ',
#  '3 BHK Flat  For Sale  In Total Environment Life Is Beautiful, Jayanagar In Jayanagar ',
#  '4+ BHK In Independent House  For Sale  In Rajajinaga  ',
#  '4+ BHK In Independent House  For Sale  In Jayanagar ',
#  '3 BHK Flat  For Sale  In Beverly Apartments In Hal 2nd Stage, Indiranagar ',
#  '2 BHK Flat  For Sale  In Maple Apartments In Indiranagar ',
#  '4 BHK Flat  For Sale  In Rrbc Piccassso In Jayanagar ',
#  '3 BHK Flat  For Sale  In Rrbc Piccassso In Jayanagar ',
#  '3 BHK Apartment  For Sale  In Adarsh Court Apartment In Jayanagar ',
#  '4+ BHK In Independent House  For Sale  In Rajaji Nagar ',
#  '1 BHK Flat  For Sale  In Rajajinagar In Rajaji Nagar ',
#  '3 BHK Flat  For Sale  In Mantri Gardens Apartment In Jayanagar ',
#  '2 BHK Flat  For Sale  In Sri Sai Durga Residency In Indira Nagar ',
# ...

# %%
nobroker = soup.find_all('div', class_="nb__1EwQz")
nobroker
# Out:
# [<div class="nb__1EwQz">Shanti Park Apartments</div>,
#  <div class="nb__1EwQz">Sagar Hospitals, 30th Cross Rd, Bannerughatta Approach Road Layout, 4th T Block East, Tilak Nagar, Jayanagar, Bengaluru, Karnataka, India</div>,
#  <div class="nb__1EwQz">30th Cross Rd, 4th T Block , Jayanagar, Bengaluru, Karnataka 560041, India</div>,
#  <div class="nb__1EwQz">Independent House, 6th Cross Rd, 2nd Block  near  SMC Enclave </div>,
#  <div class="nb__1EwQz">Independent House, 100ft Road, Ashoka Pillar Rd near Girias Jayanagar Branch</div>,
#  <div class="nb__1EwQz">Road next to Manyavar showroom</div>,
#  <div class="nb__1EwQz">Maple Apartments, Michael Palaya, 4th B Cross, 80 Feet Rd, Kalyan Nagar, H Colony, Indiranagar, Bengaluru, Karnataka 560038, India</div>,
#  <div class="nb__1EwQz">Municipal No.152, 18th main road, beside Sai Baba Temple, Jayanagara 9th Block, Jayanagar, Bengaluru, Karnataka 560056, India</div>,
# ...

# %%
HouseLocation = []

for location in nobroker:
    location = location.get_text()
    HouseLocation.append(location)
HouseLocation
# Out:
# ['Shanti Park Apartments',
#  'Sagar Hospitals, 30th Cross Rd, Bannerughatta Approach Road Layout, 4th T Block East, Tilak Nagar, Jayanagar, Bengaluru, Karnataka, India',
#  '30th Cross Rd, 4th T Block , Jayanagar, Bengaluru, Karnataka 560041, India',
#  'Independent House, 6th Cross Rd, 2nd Block  near  SMC Enclave ',
#  'Independent House, 100ft Road, Ashoka Pillar Rd near Girias Jayanagar Branch',
#  'Road next to Manyavar showroom',
#  'Maple Apartments, Michael Palaya, 4th B Cross, 80 Feet Rd, Kalyan Nagar, H Colony, Indiranagar, Bengaluru, Karnataka 560038, India',
#  'Municipal No.152, 18th main road, beside Sai Baba Temple, Jayanagara 9th Block, Jayanagar, Bengaluru, Karnataka 560056, India',
#  'Municipal No.152, 18th main road, beside Sai Baba Temple, Jayanagara 9th Block, Jayanagar, Bengaluru, Karnataka 560056, India',
#  'Adarsh Court Apartment\xa0 Adarsh Court Apartment, 8th Cross Rd, 7th Block, Jayanagar, Bengaluru, Karnataka 560070, India',
# ...

# %%
nobroker = soup.find_all('div', class_="nb__FfHqA")
nobroker
# Out:
# [<div class="nb__FfHqA">1,420 sqft</div>,
#  <div class="nb__FfHqA">1,455 sqft</div>,
#  <div class="nb__FfHqA">2,628 sqft</div>,
#  <div class="nb__FfHqA">2,240 sqft</div>,
#  <div class="nb__FfHqA">2,195 sqft</div>,
#  <div class="nb__FfHqA">1,780 sqft</div>,
#  <div class="nb__FfHqA">925 sqft</div>,
#  <div class="nb__FfHqA">4,859 sqft</div>,
#  <div class="nb__FfHqA">2,037 sqft</div>,
#  <div class="nb__FfHqA">1,990 sqft</div>,
#  <div class="nb__FfHqA">1,350 sqft</div>,
#  <div class="nb__FfHqA">650 sqft</div>,
#  <div class="nb__FfHqA">1,485 sqft</div>,
#  <div class="nb__FfHqA">1,500 sqft</div>,
#  <div class="nb__FfHqA">1,300 sqft</div>,
#  <div class="nb__FfHqA">1,378 sqft</div>,
#  <div class="nb__FfHqA">2,450 sqft</div>,
#  <div class="nb__FfHqA">1,100 sqft</div>,
#  <div class="nb__FfHqA">2,901 sqft</div>,
#  <div class="nb__FfHqA">3,600 sqft</div>,
#  <div class="nb__FfHqA">2,000 sqft</div>,
#  <div class="nb__FfHqA">1,700 sqft</div>,
# ...

# %%
BuildupArea = []

for area in nobroker:
    area = area.get_text()
    BuildupArea.append(area)
BuildupArea
# Out:
# ['1,420 sqft',
#  '1,455 sqft',
#  '2,628 sqft',
#  '2,240 sqft',
#  '2,195 sqft',
#  '1,780 sqft',
#  '925 sqft',
#  '4,859 sqft',
#  '2,037 sqft',
#  '1,990 sqft',
#  '1,350 sqft',
#  '650 sqft',
#  '1,485 sqft',
#  '1,500 sqft',
#  '1,300 sqft',
#  '1,378 sqft',
#  '2,450 sqft',
#  '1,100 sqft',
#  '2,901 sqft',
#  '3,600 sqft',
#  '2,000 sqft',
#  '1,700 sqft',
#  '1,350 sqft',
#  '3,500 sqft',
#  '650 sqft']

# %%
nobroker = soup.find_all('div', class_="nb__3q08s")
nobroker
# Out:
# [<div class="nb__3q08s"><div class="nb__4L90a" style="width:fit-content;padding:0 10px"><meta content="Title verification and loan availability" itemprop="name"/><span class="nb__2uIga"><span class="nb__2KN_6 nb__H3vjf">Not under loan</span><span style="color:#fff;border-radius:50%;padding:0 5px;background:#ccc"><span>₹</span> </span></span></div><div class="nb__4L90a" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue"><div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__FfHqA">1,420 sqft</div></div><div class="heading-7">Builtup</div></div><div class="nb__4L90a"><meta content="RoomTypes Available" itemprop="name"/><div class="font-semi-bold heading-6" id="roomType"><span>₹</span>71,643/Month</div><div class="heading-7">Estimated EMI</div></div><div class="nb__4L90a" id
# ...

# %%
EMI = []

for emi in nobroker:
    emi = emi.get_text().split('₹')[2].strip('/MonthEstimated EMI')
    EMI.append(Tes)
EMI
# Out:
# ['71,643',
#  '44,705',
#  '1.72 Lac',
#  '83,679',
#  '2.96 Lac',
#  '91,703',
#  '37,254',
#  '3.91 Lac',
#  '1.69 Lac',
#  '2.01 Lac',
#  '1.96 Lac',
#  '28,657',
#  '94,568',
#  '68,777',
#  '65,911',
#  '56,168',
#  '2.01 Lac',
#  '57,314',
#  '2.72 Lac',
#  '3.15 Lac',
#  '45,278',
#  '1.43 Lac',
#  '71,643',
#  '1.58 Lac',
#  '24,072']

# %%
Price = []

for rate in nobroker:
    rate = rate.get_text().split('₹')[3]
    Price.append(rate)
Price
# Out:
# ['1.25 Crores',
#  '78 Lacs',
#  '3 Crores',
#  '1.46 Crores',
#  '5.16 Crores',
#  '1.6 Crores',
#  '65 Lacs',
#  '6.83 Crores',
#  '2.94 Crores',
#  '3.5 Crores',
#  '3.42 Crores',
#  '50 Lacs',
#  '1.65 Crores',
#  '1.2 Crores',
#  '1.15 Crores',
#  '98 Lacs',
#  '3.5 Crores',
#  '1 Crore',
#  '4.75 Crores',
#  '5.5 Crores',
#  '79 Lacs',
#  '2.5 Crores',
#  '1.25 Crores',
#  '2.75 Crores',
#  '42 Lacs']

# %%
data = pd.DataFrame()
data['HouseTitle'] = HouseTitle
data['HouseLocation'] = HouseLocation
data['EMI (₹)'] = EMI
data['Price (₹)'] = Price
data['BuildupArea'] = BuildupArea
data.head(25)
# Out:
#                                            HouseTitle  \
# 0   3 BHK Flat  For Sale  In Shanti Park Apartment...
# 1   3 BHK Flat  For Sale  In Madhavaram Metropolit...
# 2   3 BHK Flat  For Sale  In Total Environment Lif...
# 3   4+ BHK In Independent House  For Sale  In Raja...
# 4   4+ BHK In Independent House  For Sale  In Jaya...
# 5   3 BHK Flat  For Sale  In Beverly Apartments In...
# 6   2 BHK Flat  For Sale  In Maple Apartments In I...
# 7   4 BHK Flat  For Sale  In Rrbc Piccassso In Jay...
# 8   3 BHK Flat  For Sale  In Rrbc Piccassso In Jay...
# 9   3 BHK Apartment  For Sale  In Adarsh Court Apa...
# 10  4+ BHK In Independent House  For Sale  In Raja...
# 11  1 BHK Flat  For Sale  In Rajajinagar In Rajaji...
# 12  3 BHK Flat  For Sale  In Mantri Gardens Apartm...
# 13  2 BHK Flat  For Sale  In Sri Sai Durga Residen...
# 14  3 BHK Flat  For Sale  In Vaishali Residency In...
# 15  2 BHK Apartment  For Sale  In Benaka Towers In...
# ...

# %%
data.to_csv('NoBroker Webscrapping data', index=False)
